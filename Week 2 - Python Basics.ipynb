# %% [markdown]
# # ISB02303302 – Statistics for Business
# ## Classroom Exercise Week 2: Python Basics

# %% [markdown]
# ### Python Data Types

# %% [markdown]
# Python is a computer language that follows the object-oriented paradigm. Python encompasses a diverse range of object types. Let us commence our discussion by examining the most prevalent categories of objects, namely integers, floats, and strings. In the context of Python programming, character strings, commonly referred to as strings, are utilised for the purpose of representing and manipulating textual data. Integers or whole numbers (e.g., -1, 0, 100) and floats, which represent fractional numbers (e.g., 3.14, -42.0), are the prevailing numerical types. The examples are provided below. Please execute by pressing the <code>shift + enter key</code> simultaneously.

# %%
# String addition

addition = "3" + "5"
print(addition)
# Out:
# 35

# %%
# Integer

11
# Out:
# 11

# %%
# Float

2.14
# Out:
# 2.14

# %%
# String

"Hello, Python 101!"
# Out:
# 'Hello, Python 101!'

# %% [markdown]
# Using the `type()` function, Python can determine the data type. Python represents integers as `int`, fractions as `float`, and character strings as `str`.

# %%
# Type of 12

type(12)
# Out:
# int

# %%
# Type of 2.14

type(2.14)
# Out:
# float

# %%
# Type of "Hello, Python 101!"

type("Hello, Python 101!")
# Out:
# str

# %% [markdown]
# Now use the `type()` function to recognize the data type of the `first_result` variable which is the sum of `3 + 2` and `second_result` variable which is the sum of `3 + 2.5`. What can you infer from the result?

# %%
first_result = 3 + 5
second_result = 3 + 2.5

print(type(first_result))
print(type(second_result))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### Data type conversion

# %% [markdown]
# You can convert the data type in Python. This process is called typecasting. For example, you can change `int` to `float` (eg: 2 becomes 2.0). Let's try:

# %%
# Verify that this is an integer

type(2)
# Out:
# int

# %%
# Convert 2 to a float

float(2)
# Out:
# 2.0

# %%
# Convert integer 2 to a float and check its type

type(float(2))
# Out:
# float

# %%
# Casting 1.1 to integer will result in loss of information

int(7.9)
# Out:
# 7

# %%
# Convert a string into an integer

int("1")
# Out:
# 1

# %%
# Convert a string into an integer with error

int("1 or 2 people")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 # Convert a string into an integer with error
# ----> 3 int("1 or 2 people")
#
# ValueError: invalid literal for int() with base 10: '1 or 2 people'

# %%
# Convert the string "1.2" into a float

float("1.2")
# Out:
# 1.2

# %%
# Convert an integer to a string

str(1)
# Out:
# '1'

# %%
# Convert a float to a string

str(1.2)
# Out:
# '1.2'

# %%
# Boolean data type
# Value true

True
# Out:
# True

# %%
# Boolean data type
# Value false

False
# Out:
# False

# %%
# Type of True

type(True)
# Out:
# bool

# %%
# Type of False

type(False)
# Out:
# bool

# %%
# Convert True to int

int(True)
# Out:
# 1

# %%
# Convert 0 to boolean

bool(0)
# Out:
# False

# %%
# Convert 1 to boolean

bool(1)
# Out:
# True

# %%
# Convert 2 to boolean

bool(2)
# Out:
# True

# %%
# Convert True to float

float(True)
# Out:
# 1.0

# %% [markdown]
# #### Do the following practice questions
#
# State the data type resulting from: 6 / 2

# %%
type(6/2)
# Out:
# float

# %% [markdown]
# State the data type resulting from: 6 // 2
# (Note the double slash)

# %%
type(6//2)
# Out:
# int

# %% [markdown]
# Check if the the letter 'd' is a member of the value in 'hw' variable

# %%
hw = 'Hello World'
'd' in hw
# Out:
# True

# %% [markdown]
# ### Expressions and Variables

# %% [markdown]
# Expressions in Python can include operations between appropriate data types (for example: between integer and float). Consider examples of basic arithmetic operations as below:

# %%
# Addition operation expression

43 + 60 + 16 + 41
# Out:
# 160

# %%
# Subtraction operation expression

50 - 60
# Out:
# -10

# %%
# Multiplication operation expression

5 * 5
# Out:
# 25

# %%
# Division operation expression

25 / 5
# Out:
# 5.0

# %%
# Division operation expression

25 / 6
# Out:
# 4.166666666666667

# %%
# Integer division operation expression

25 // 5
# Out:
# 5

# %%
# Integer division operation expression

25 // 6
# Out:
# 4

# %%
# Exponential operation expression

2 ** 8
# Out:
# 256

# %% [markdown]
# #### Do the following practice questions
#
# Flights from Surabaya to Bangkok take 264 minutes. How many hours and how many minutes is this flight?

# %%
total_minutes = 264
hours = total_minutes // 60
minutes = total_minutes % 60

print("Flight Surabaya - Bangkok is {} hours and {} minute.".format(hours, minutes))
# Out:
# Flight Surabaya - Bangkok is 5 hours and 5 minute.

# %% [markdown]
# Python evaluates mathematical expressions in accordance with accepted mathematical conventions. The following order of mathematical operations can be observed:
#
# <img src="https://miro.medium.com/max/1400/1*XCOKzXaTZVWkU-g7ZGdqKQ.png" alt="Operator Precedence" style="width:640px;height:360px;">

# %%
# Mathematical expression

30 + 2 * 60
# Out:
# 150

# %%
# Mathematical expression

(30 + 2) * 60
# Out:
# 1920

# %% [markdown]
# Just like most programming languages, we can store values in variables, so we can use them later.

# %%
# Store value into variable

x = 43 + 60 + 16 + 41

# %%
# Print out the value in variable

x
# Out:
# 160

# %%
# Use another variable to store the result of the operation between variable and value

y = x / 60
y
# Out:
# 2.6666666666666665

# %%
# Overwrite variable with new value

x = x / 60
x
# Out:
# 2.6666666666666665

# %% [markdown]
# It's a good habit to use meaningful variable names, so that you and others can read the code and understand it more easily:

# %%
# Name the variables meaningfully

total_min = 43 + 42 + 57 # Total length of albums in minutes
total_min
# Out:
# 142

# %%
# Name the variables meaningfully

total_hours = total_min / 60 # Total length of albums in hours 
total_hours
# Out:
# 2.3666666666666667

# %% [markdown]
# #### Do the following practice questions
#
# Calculate the value of `x` where `x = 3 + 2 * 2`

# %%
x = 3 + 2 * 2
x
# Out:
# 7

# %% [markdown]
# Calculate the value of `y` where `y = (3 + 2) * 2`

# %%
y = (3 + 2) * 2
y
# Out:
# 10

# %% [markdown]
# Calculate the value of `z` where `z = x + y`

# %%
z = x + y
z
# Out:
# 17

# %% [markdown]
# ### String Operations

# %% [markdown]
# A string is a sequence of characters in Python. Strings are typed with either single or double quotation. Understanding strings as ordered sequences of characters is important.

# %%
# Use quotation marks for defining string

"universitas ciputra"
# Out:
# 'universitas ciputra'

# %%
# Use single quotation marks for defining string

'universitas ciputra'
# Out:
# 'universitas ciputra'

# %%
# Digitals and spaces in string

'1 2 3 4 5 6 '
# Out:
# '1 2 3 4 5 6 '

# %%
# Special characters in string

'@#2_#]&*^%$'
# Out:
# '@#2_#]&*^%$'

# %%
# Print the string

print("hello!")
# Out:
# hello!

# %%
# Assign string to variable

campus = 'universitas ciputra'
campus
# Out:
# 'universitas ciputra'

# %%
# Print the first element in the string

print(campus[0])
# Out:
# u

# %%
# Print the element on index 6 in the string

print(campus[6])
# Out:
# s

# %%
# Print the last element in the string

print(campus[-1])
# Out:
# a

# %%
first_result = 18 + 21.5

second_result = 18 + 251

print(type(first_result))

print(type(second_result))
# Out:
# <class 'float'>
# <class 'int'>

# %% [markdown]
# #### String Slicing
# Using slicing, we can extract multiple characters from a string; for example, we can extract elements 0 to 4 or 8 to 12.

# %%
# Take the slice on variable Name with only index 0 to index 3

campus[0:4]
# Out:
# 'univ'

# %%
# Take the slice on variable Name with only index 8 to index 11

campus[8:12]
# Out:
# 'tas '

# %% [markdown]
# #### String Striding
#
# We can also retrieve elements based on certain rules, for example with a '2' signifying that we are selecting every second element.

# %%
# Get every second element. The elements on index 0, 2, 4, ...

campus[::2]
# Out:
# 'uiestscpta'

# %%
# Get every second element in the range from index 0 to index 4

campus[0:5:2]
# Out:
# 'uie'

# %%
float("2.1") * 1
# Out:
# 2.1

# %% [markdown]
# #### Additional Challenge #1 (Optional)
# The camelCase convention is a widely used variable name practise in which each word within a compound word is capitalised, with the exception of the initial word. CamelCase is a commonly employed convention by software developers for naming variables in source code. Some examples of camelCase in programming are variables such as "myArray" and "getCommandException." The objective is to transform a given string input into an output string in camelCase format.
#
# For example:
#
# *   input: "I am a Proud ISB Students"
# *   output: "iAmAProudIsbStudents"
#
# hint: use split(), lower(), capitalize(), and join() function

# %%
def to_camel_case(input_string):
    result = ""
    words = input_string.split()
    if words[0]:
      lower_first_word = words[0].lower()
      result += lower_first_word

    for range in words[1:]:
      capitalized_word = range.capitalize()
      result += capitalized_word
    return result

input_string = 'I am a Proud ISB Students'
camel_case_result = to_camel_case(input_string)
print(camel_case_result)
# Out:
# iAmAProudIsbStudents

# %% [markdown]
# #### Additional Challenge #2 (Optional)
# Encryption is the process of encoding a message or file so that it can only be deciphered by authorised individuals. Encryption employs an algorithm to scramble, or encrypt, data and a key to decipher, or decrypt, the information for the receiving party. Your mission is to generate a straightforward encryption of the String by shifting its Unicode number.
#
# For example:
#
# *   input: "I am a proud ISB student"
# *   shift by: 1 unicode
# *   output: "J!bn!b!qspve!JTC!tuvefou"
#
# hint: use chr() and ord() function

# %%
def my_encryption(my_input):
    decrypted = ""

    for char in my_input:
      decrypted += chr(ord(char) + 1)

    return decrypted

input_string = 'I am a Proud ISB Students'
encryption_result = my_encryption(input_string)
print(encryption_result)
# Out:
# J!bn!b!Qspve!JTC!Tuvefout

# %% [markdown]
# <center>=== Let's Call it a Day. ===</center>
