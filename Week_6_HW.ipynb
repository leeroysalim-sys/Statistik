# %%
# Import necessary library

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# Frequency Table
# Grouping of qualitative data into mutually exclusive classes showing the number of observations in each class.
# Dataset source: 'https://raw.githubusercontent.com/CarrenP/files/refs/heads/main/penguins_size.csv'

# %%
# import the df from the link above
url = 'https://raw.githubusercontent.com/CarrenP/files/refs/heads/main/penguins_size.csv'
df = pd.read_csv(url, sep = ",")
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
# menunjukan informasi mengenai tabel, dari data type, jumlah data hingga nama kolum.
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 18.9 KB

# %%
# Count the penguins based on their species
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
# create a pie chart to visualise the species, explain your finding in at least 2 sentences.
df['species'].value_counts().plot(
kind='pie', figsize=(10,6),
autopct='%1.2f%%', legend=True
)
plt.title('Penguin Distribution by Species')
plt.show()

# The pie chart shows the proportion of each penguin species in the dataset. Adelie appears to be the most common species, followed by Gentoo and Chinstrap, indicating a varied population across the islands.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # create a bar chart to visualise the spesies, explain your findng in at least 2 setences.
# ----> 2 df.groupby('species') ['island'].sum().plot(
#       3 kind='pie', y='island', figsize=(10,6),
#       4 autopct='%1.2f%%', legend=True
#       5 )
#       6 plt.title('Penguin Distribution by ISland')
#       7 plt.show()
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_matplotlib\core.py:2134, in PiePlot.__init__(self, data, kind, **kwargs)
#    2132 def __init__(self, data: Series | DataFrame, kind=None, **kwargs) -> None:
#    2133     data = data.fillna(value=0)
# -> 2134     lt_zero = data < 0
#    2135     if isinstance(data, ABCDataFrame) and lt_zero.any().any():
#    2136         raise ValueError(f"{self._kind} plot doesn't allow negative values")
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6735, in Series._cmp_method(self, other, op)
#    6732 lvalues = self._values
#    6733 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6735 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6737 return self._construct_result(res_values, name=res_name, other=other)
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:341, in comparison_op(left, right, op)
#     332         raise ValueError(
#     333             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     334         )
#     336 if should_extension_dispatch(lvalues, rvalues) or (
#     337     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     338     and lvalues.dtype != object
#     339 ):
#     340     # Call the method on lvalues
# --> 341     res_values = op(lvalues, rvalues)
#     343 # TODO: but not pd.NA?
#     344 elif (is_scalar(rvalues) or rvalues_is_zerodim) and isna(rvalues):
#     345     # numpy does not like comparisons vs None
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File c:\Users\leero\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\string_.py:1220, in StringArray._cmp_method(self, other, op)
#    1217 else:
#    1218     # logical
#    1219     result = np.zeros(len(self._ndarray), dtype="bool")
# -> 1220     result[valid] = op(self._ndarray[valid], other)
#    1221     res_arr = BooleanArray(result, mask)
#    1222     if self.dtype.na_value is np.nan:
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
# Display the data distribution of culmen length by island using box plot,explain your findng in at least 2 setences.
